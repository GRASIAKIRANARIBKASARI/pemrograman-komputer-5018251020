# %% [markdown]
# <a href="https://colab.research.google.com/github/GRASIAKIRANARIBKASARI/pemrograman-komputer-5018251020/blob/main/Week02/W02_Engineering_Calculator_5018251020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# Nama : Grasia Kirana Ribkasari
# NRP : 5018251020
# Kelas : A

# %%
speed_kmh = float(input("Enter speed [km/h]: "))
speed_ms = speed_kmh / 3.6
print(f"Speed = {speed_ms:.2f} m/s")
# Out:
# Enter speed [km/h]: 12
# Speed = 3.33 m/s

# %%
power_kw = float(input("Enter power [kW]: "))
power_w = power_kw * 1000
print(f"Power = {power_w: .2f} W")
# Out:
# Enter power [kW]: 23
# Power =  23000.00 W

# %%
voltage = float(input("Enter voltage[V]: "))
current = float(input("Enter current [A]: "))
time_hour = float(input("Enter operating time [hour]: "))

power = voltage * current
energy = power * time_hour
print("===== ELECTRICL CALCULATION =====")
print(f"Voltage = {voltage: .2f} V")
print(f"Current = {current: .2f} A")
print(f"Power = {power: .2f} W")
print(f"Operating Time = {time_hour: .2f} hour")
print(f"Energy = {energy: .2f} Wh")
# Out:
# Enter voltage[V]: 21
# Enter current [A]: 2.0
# Enter operating time [hour]: 1.9
# ===== ELECTRICL CALCULATION =====
# Voltage =  21.00 V
# Current =  2.00 A
# Power =  42.00 W
# Operating Time =  1.90 hour
# Energy =  79.80 Wh

# %%
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# High power : False
# High voltage : False
# Both conditions : False
# Any condition : False

# %%
voltage = float(input("Enter voltage[V]: "))
current = float(input("Enter current [A]: "))
time_hour = float(input("Enter operating time [hour]: "))

power = voltage * current
energy = power * time_hour
print("===== ELECTRICL CALCULATION =====")
print(f"Voltage = {voltage: .2f} V")
print(f"Current = {current: .2f} A")
print(f"Power = {power: .2f} W")
print(f"Operating Time = {time_hour: .2f} hour")
print(f"Energy = {energy: .2f} Wh")
# Out:
# Enter voltage[V]: 12
# Enter current [A]: 5.0
# Enter operating time [hour]: 2.0
# ===== ELECTRICL CALCULATION =====
# Voltage =  12.00 V
# Current =  5.00 A
# Power =  60.00 W
# Operating Time =  2.00 hour
# Energy =  120.00 Wh

# %%
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# High power : False
# High voltage : False
# Both conditions : False
# Any condition : False

# %%
voltage = float(input("Enter voltage[V]: "))
current = float(input("Enter current [A]: "))
time_hour = float(input("Enter operating time [hour]: "))

power = voltage * current
energy = power * time_hour
print("===== ELECTRICL CALCULATION =====")
print(f"Voltage = {voltage: .2f} V")
print(f"Current = {current: .2f} A")
print(f"Power = {power: .2f} W")
print(f"Operating Time = {time_hour: .2f} hour")
print(f"Energy = {energy: .2f} Wh")
# Out:
# Enter voltage[V]: 24
# Enter current [A]: 8.5
# Enter operating time [hour]: 3.0
# ===== ELECTRICL CALCULATION =====
# Voltage =  24.00 V
# Current =  8.50 A
# Power =  204.00 W
# Operating Time =  3.00 hour
# Energy =  612.00 Wh

# %%
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# High power : True
# High voltage : False
# Both conditions : False
# Any condition : True

# %%
voltage = float(input("Enter voltage[V]: "))
current = float(input("Enter current [A]: "))
time_hour = float(input("Enter operating time [hour]: "))

power = voltage * current
energy = power * time_hour
print("===== ELECTRICL CALCULATION =====")
print(f"Voltage = {voltage: .2f} V")
print(f"Current = {current: .2f} A")
print(f"Power = {power: .2f} W")
print(f"Operating Time = {time_hour: .2f} hour")
print(f"Energy = {energy: .2f} Wh")
# Out:
# Enter voltage[V]: 48
# Enter current [A]: 10.0
# Enter operating time [hour]: 1.5
# ===== ELECTRICL CALCULATION =====
# Voltage =  48.00 V
# Current =  10.00 A
# Power =  480.00 W
# Operating Time =  1.50 hour
# Energy =  720.00 Wh

# %%
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True

# %% [markdown]
# ## Short Reflection
#
# 1. int itu bilangan bulat, float itu bilangan desimal
# 2. Karena input () hasilnya string, harus dikonversi float () biar bisa dihitung
# 3. = itu ngasih nilai, == itu banding nilai
# 4. and itu true kalau semua benar, or itu true kalau salah satu benar
# 5. Beberapa kali aku ada error karena = jadi hasilnya gamau keluar. Terus aku benahi dengan memprhatikan satu satu code yang saya tuiskan dan warning di bawahnya.
